# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time
import requests
import pandas as pd

# %%
driver = webdriver.Chrome('c:/pydata/chromedriver.exe')
time.sleep(2)
url = 'https://www.melon.com/chart/day/index.htm'
driver.get(url)
driver.implicitly_wait(10)

html = driver.page_source
soup = bs(html,'html.parser')
tbody_soup = soup.find('tbody')
tr_soup = tbody_soup.find_all('tr')

tr_soup[0].find('span', class_ = 'rank').get_text()
print(tr_soup[0].find('div',class_ = 'ellipsis rank01').get_text())
print(tr_soup[0].find('span',class_="checkEllipsis").get_text())
print(tr_soup[0].find('div',class_ = 'ellipsis rank03').get_text())
# Out:
# C:\Users\l8822\AppData\Local\Temp\ipykernel_14864\1028079673.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('c:/pydata/chromedriver.exe')
# TOMBOY
#
# (여자)아이들
#
# I NEVER DIE

# %% [markdown]
# ### 멜론 순위가져오기

# %%
driver = webdriver.Chrome('c:/pydata/chromedriver.exe')
time.sleep(2)
url = 'https://www.melon.com/chart/day/index.htm'
driver.get(url)
driver.implicitly_wait(10)

html = driver.page_source
soup = bs(html,'html.parser')
# driver.quit()
tbody_soup = soup.find('tbody')
tr_soup = tbody_soup.find_all('tr')
li = []

for tr in tr_soup:

    rank = tr.find('span', class_ = 'rank').get_text()
    title = tr.find('div',class_ = 'ellipsis rank01').get_text().replace('\n','')
    art = tr.find('span',class_="checkEllipsis").get_text()
    album = tr.find('div',class_ = 'ellipsis rank03').get_text().replace('\n','')
    li.append({'순위':rank,'제목':title,'art':art,'앨범':album})
df = pd.DataFrame(li)
df
# Out:
# C:\Users\l8822\AppData\Local\Temp\ipykernel_14864\3099905979.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('c:/pydata/chromedriver.exe')
#      순위                            제목  \
# 0     1                        TOMBOY
# 1     2          GANADARA (Feat. 아이유)
# 2     3                Feel My Rhythm
# 3     4                          INVU
# 4     5                        듣고 싶을까
# ..  ...                           ...
# 95   96                  별빛 같은 나의 사랑아
# 96   97                          HERO
# 97   98                           끝사랑
# 98   99  쉬어 (Feat. MINO) (Prod. GRAY)
# 99  100                그날에 나는 맘이 편했을까
#
#                                                   art  \
# 0                                             (여자)아이들
# 1                                                 박재범
# 2                                   Red Velvet (레드벨벳)
# 3                                        태연 (TAEYEON)
# 4                                       MSG워너비(M.O.M)
# ..                                                ...
# 95                                                임영웅
# 96                                                임영웅
# 97                                                임영웅
# 98  아넌딜라이트(Anandelight), unofficialboyy, BE'O (비오)...
# 99                                                이예준
#
#                                            앨범
# 0                                 I NEVER DIE
# 1                                    GANADARA
# 2   ‘The ReVe Festival 2022 - Feel My Rhythm’
# 3                        INVU - The 3rd Album
# 4                                      듣고 싶을까
# ..                                        ...
# 95                               별빛 같은 나의 사랑아
# 96                                       HERO
# 97                             사랑의 콜센타 PART61
# 98                         쇼미더머니 10 Episode 1
# 99                             그날에 나는 맘이 편했을까
#
# [100 rows x 4 columns]
